# %%
import cv2
import matplotlib.pyplot as plt

# %%
imagem = cv2.imread("JesusCristo1.jpg")

# %%
plt.imshow(imagem)

# %%
imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagem_rgb)

# %%
imagem_rgb.shape
# Out:
# (3079, 2141, 3)

# %%
imagem_gray = cv2.cvtColor(imagem_rgb, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(imagem_gray, cmap = "gray")

# %%
imagem = cv2.imread("JesusCristo1.jpg")
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagem)

# %%
imagem.shape
# Out:
# (3079, 2141, 3)

# %%
imagem_roi = imagem[300:1300, 700:1400]
plt.imshow(imagem_roi)

# %%
imagem_roibgr = cv2.cvtColor(imagem_roi, cv2.COLOR_RGB2BGR)
cv2.imwrite("imagem_roi.jpeg", imagem_roibgr)
# Out:
# True
